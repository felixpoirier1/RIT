# %%
from tradeapp.tradeapp import TradingApp
import matplotlib.pyplot as plt
import time
import pandas
import numpy as np

# %%
app = TradingApp("9999", "0CEN4JP9")
#app.postOrder("BUY", "RITC", 1000)

# %%
tendies = []
while True:
    tend = app.getTenders()
    if tend != None:
        tendies.append(tend)
        print(tend)
    time.sleep(5)

# %%
tendies_dict = {list(tendies[i].keys())[0]: list(tendies[i].values())[0] for i in range(len(tendies))}
tendies_df = pandas.DataFrame(tendies_dict).transpose().set_index("tick")
tendies_df
# Out:
#      period expires                                            caption ticker  \
# tick
# 18        1      24  An institution would like to SELL 93000 shares...   RITC
# 44        1      50  An institution would like to SELL 85000 shares...   RITC
# 81        1      87  An institution would like to BUY 88000 shares ...   RITC
# 110       1     116  An institution would like to SELL 73000 shares...   RITC
# 144       1     150  An institution would like to SELL 94000 shares...   RITC
# 177       1     183  An institution would like to BUY 89000 shares ...   RITC
# 195       1     201  An institution would like to SELL 96000 shares...   RITC
# 230       1     236  An institution would like to SELL 95000 shares...   RITC
#
#      quantity action is_fixed_bid  price
# tick
# 18    93000.0    BUY         True  24.95
# 44    85000.0    BUY         True  24.77
# 81    88000.0   SELL         True  24.74
# 110   73000.0    BUY         True  24.04
# 144   94000.0    BUY         True   24.6
# 177   89000.0   SELL         True  24.99
# 195   96000.0    BUY         True  24.86
# 230   95000.0    BUY         True  24.76

# %%
df_RITC_hist = app.getSecuritiesHistory("RITC").set_index("tick")[::-1]
df_BULL_hist = app.getSecuritiesHistory("BULL").set_index("tick")[::-1]
df_BEAR_hist = app.getSecuritiesHistory("BEAR").set_index("tick")[::-1]
df_USD_hist = app.getSecuritiesHistory("USD").set_index("tick")[::-1]

# %%
df = pandas.concat([df_RITC_hist.close, df_BULL_hist.close, df_BEAR_hist.close, df_USD_hist.close], axis=1)
df.columns = ["RITC", "BULL", "BEAR", "USD"]
df["RITC_undrlyng"] = df["BULL"] + df["BEAR"]
df["RITC"] = df["RITC"] * df["USD"]

# %%
commission = 0.02 # per share
slippage = 0.05 # per share
adj_commision = commission*2 + slippage

# %%
f, axarr = plt.subplots(2, figsize=(20,10), sharex=True)
axarr[0].plot(df.index, df["RITC_undrlyng"], c="b", linewidth=1, label=r"RITC underlying $(BULL - BEAR)/USD$")
axarr[0].plot(df.index, df["RITC"], c="r", linewidth=2, label="RITC (USD adjusted)")
# for i in range(len(tendies_df)):
#     axarr[0].axvline(x=tendies_df.index[i], color='black', linewidth=0.5, linestyle='--')
#     axarr[0].axvline(x=tendies_df.iloc[i]["expires"], color='black', linewidth=0.5, linestyle='--')
#     axarr[0].axvspan(tendies_df.index[i], tendies_df.iloc[i]["expires"], alpha=0.1, color='green' if tendies_df.iloc[i]["action"] == "BUY" else "red")
#     axarr[0].scatter(tendies_df.index[i], tendies_df.iloc[i]["price"]*df.iloc[tendies_df.index[i]]["USD"], c="black", marker="x", s=100)

axarr[0].set_ylabel('Price in CAD')
axarr[0].grid()
axarr[0].legend()
axarr[0].set_title('RITC underlying vs RITC price timeseries')

axarr[1].plot(df.index, df["RITC_undrlyng"] - df["RITC"], c="black", label=r"RITC underlying - RITC")
axarr[1].set_title('Price differential')
axarr[1].set_ylabel('Price difference in CAD')
axarr[1].fill_between(df.index, df["RITC_undrlyng"] - df["RITC"], adj_commision, where=df["RITC_undrlyng"] - df["RITC"] > adj_commision, facecolor='green', alpha=0.5, label="profit")
axarr[1].fill_between(df.index, df["RITC_undrlyng"] - df["RITC"], -adj_commision*2, where=df["RITC_undrlyng"] - df["RITC"] < -adj_commision*2, facecolor='green', alpha=0.5)
axarr[1].legend()
axarr[1].axhline(y=0, color='black', linestyle='--')
axarr[1].set_xlabel('tick')
# Out:
# Text(0.5, 0, 'tick')

# %%
import scipy.stats as ss

# %%
fig, axs = plt.subplots(2, 2, figsize=(20,10))

pct_ch_df = df.pct_change().dropna()
pct_ch_df = pct_ch_df[["BULL", "BEAR", "RITC", "RITC_undrlyng"]]
# estimate Kernel Density and plot
for i in range(2):
    for j in range(2):
        axs[i,j].set_title(pct_ch_df.columns[i*2+j])
        axs[i,j].hist(pct_ch_df[pct_ch_df.columns[i*2+j]], alpha=0.5, bins=20)

        x = np.linspace(pct_ch_df[pct_ch_df.columns[i*2+j]].min(), pct_ch_df[pct_ch_df.columns[i*2+j]].max(), 301)
        kde = ss.gaussian_kde(pct_ch_df[pct_ch_df.columns[i*2+j]])
        axs[i,j].plot(x, kde.pdf(x), linestyle = "--", c="black", label='KDE')
        axs[i,j].legend()

# %%
securities = list(app.getSecurities().keys())
bidask = {sec: app.getSecuritiesBook(sec) for sec in securities}

# %%
for sec in securities:
    bidask[sec]["bids"]["ev_vwap"] = ((bidask[sec]["bids"]["price"] * bidask[sec]["bids"]["quantity"])/bidask[sec]["bids"]["quantity"]).expanding().mean()
    bidask[sec]["asks"]["ev_vwap"] = ((bidask[sec]["asks"]["price"] * bidask[sec]["asks"]["quantity"])/bidask[sec]["asks"]["quantity"]).expanding().mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 for sec in securities:
#       2     bidask[sec]["bids"]["ev_vwap"] = ((bidask[sec]["bids"]["price"] * bidask[sec]["bids"]["quantity"])/bidask[sec]["bids"]["quantity"]).expanding().mean()
#       3     bidask[sec]["asks"]["ev_vwap"] = ((bidask[sec]["asks"]["price"] * bidask[sec]["asks"]["quantity"])/bidask[sec]["asks"]["quantity"]).expanding().mean()
#
# NameError: name 'securities' is not defined

# %%
import seaborn as sns


fig, ax = plt.subplots(3, 1, figsize=(8, 12))
fig.subplots_adjust(hspace=0.5)

for i, val in enumerate(securities[2:]):
    # bid side
    sns.ecdfplot(x="price", weights="quantity", stat="count", complementary=True, data=bidask[val]["bids"], ax=ax[i], color='g')
    # ask side
    sns.ecdfplot(x="price", weights="quantity", stat="count", data=bidask[val]["asks"], ax=ax[i], color='r')
    ax[i].set_title(val)
    ax[i].set_xlabel("Price")
    ax[i].set_ylabel("Amount")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       4 fig, ax = plt.subplots(3, 1, figsize=(8, 12))
#       5 fig.subplots_adjust(hspace=0.5)
# ----> 7 for i, val in enumerate(securities[2:]):
#       8     # bid side
#       9     sns.ecdfplot(x="price", weights="quantity", stat="count", complementary=True, data=bidask[val]["bids"], ax=ax[i], color='g')
#      10     # ask side
#
# NameError: name 'securities' is not defined

# %%
bidask_BEAR["bids"]
# Out:
#           period  tick trader_id ticker  quantity  price   type action  \
# order_id
# 2433           1   168        h1   BEAR    1000.0  16.74  LIMIT    BUY
# 2394           1   166      ANON   BEAR    7300.0  16.73  LIMIT    BUY
# 2372           1   165        h1   BEAR    1000.0  16.70  LIMIT    BUY
# 2359           1   164      ANON   BEAR    7200.0  16.69  LIMIT    BUY
# 2382           1   165      ANON   BEAR    9100.0  16.69  LIMIT    BUY
# 2347           1   163        h1   BEAR     100.0  16.68  LIMIT    BUY
# 2334           1   162        h1   BEAR    1000.0  16.67  LIMIT    BUY
# 2432           1   168      ANON   BEAR    9800.0  16.66  LIMIT    BUY
# 2285           1   159      ANON   BEAR    8100.0  16.65  LIMIT    BUY
# 2245           1   156      ANON   BEAR    7400.0  16.59  LIMIT    BUY
# 2270           1   157      ANON   BEAR    9600.0  16.57  LIMIT    BUY
# 2253           1   156      ANON   BEAR    8600.0  16.56  LIMIT    BUY
# 2226           1   154      ANON   BEAR    8400.0  16.54  LIMIT    BUY
# 2400           1   166      ANON   BEAR   10100.0  16.54  LIMIT    BUY
# 2274           1   158      ANON   BEAR   10800.0  16.53  LIMIT    BUY
# 2295           1   159      ANON   BEAR    9700.0  16.50  LIMIT    BUY
# 2353           1   164      ANON   BEAR   10600.0  16.47  LIMIT    BUY
# 2328           1   161      ANON   BEAR   10000.0  16.46  LIMIT    BUY
# 2219           1   154      ANON   BEAR   10100.0  16.42  LIMIT    BUY
# 2314           1   161      ANON   BEAR    9100.0  16.40  LIMIT    BUY
#
#           quantity_filled   vwap status
# order_id
# 2433                  0.0    NaN   OPEN
# 2394               3000.0  16.73   OPEN
# 2372                  0.0    NaN   OPEN
# 2359                  0.0    NaN   OPEN
# 2382                  0.0    NaN   OPEN
# 2347                  0.0    NaN   OPEN
# 2334                  0.0    NaN   OPEN
# 2432                  0.0    NaN   OPEN
# 2285               1600.0  16.65   OPEN
# 2245                  0.0    NaN   OPEN
# 2270                  0.0    NaN   OPEN
# 2253                  0.0    NaN   OPEN
# 2226                  0.0    NaN   OPEN
# 2400                  0.0    NaN   OPEN
# 2274                  0.0    NaN   OPEN
# 2295                  0.0    NaN   OPEN
# 2353                  0.0    NaN   OPEN
# 2328                  0.0    NaN   OPEN
# 2219                  0.0    NaN   OPEN
# 2314                  0.0    NaN   OPEN

# %%
app.getTenders()
# Out:
# {3541: {'period': 1,
#   'tick': 235,
#   'expires': 241,
#   'caption': 'An institution would like to BUY 71000 shares of RITC from you at a price of 24.26.  Would you like to SELL the shares to them?',
#   'ticker': 'RITC',
#   'quantity': 71000.0,
#   'action': 'SELL',
#   'is_fixed_bid': True,
#   'price': 24.26}}

# %%
tend = app.getTenders()

# %%
tend
# Out:
# {541: {'period': 1,
#   'tick': 47,
#   'expires': 53,
#   'caption': 'An institution would like to SELL 98000 shares of RITC to you at a price of 24.55.  Would you like to BUY the shares from them?',
#   'ticker': 'RITC',
#   'quantity': 98000.0,
#   'action': 'BUY',
#   'is_fixed_bid': True,
#   'price': 24.55}}
